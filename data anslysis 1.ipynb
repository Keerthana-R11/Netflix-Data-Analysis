# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

# %%
data=pd.read_csv("C:/Users/keert/Downloads/archive (3)/netflix_titles.csv")
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.isnull().sum()/100*2
# Out:
# show_id          0.00
# type             0.00
# title            0.00
# director        52.68
# cast            16.50
# country         16.62
# date_added       0.20
# release_year     0.00
# rating           0.08
# duration         0.06
# listed_in        0.00
# description      0.00
# dtype: float64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.rename(columns={'cast':'actors/actresses','date_added':'Netflix_date_added','listed_in':'categories'},inplace=True)

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                        actors/actresses        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data_clean = data.dropna(subset=['director'],inplace=True)
data_clean

# %%
data.isnull().sum()
# Out:
# show_id                 0
# type                    0
# title                   0
# director                0
# actors/actresses      473
# country               422
# Netflix_date_added      0
# release_year            0
# rating                  1
# duration                3
# categories              0
# description             0
# dtype: int64

# %%
data['actors/actresses'] = data['actors/actresses'].fillna('unknown')

# %%
data['country']=data['country'].fillna('unknown country')

# %%
data['duration']=data['duration'].fillna('not available')

# %%
data.fillna({'rating': data['rating'].mode()[0]}, inplace=True)

# %%
data.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director              0
# actors/actresses      0
# country               0
# Netflix_date_added    0
# release_year          0
# rating                0
# duration              0
# categories            0
# description           0
# dtype: int64

# %%
data.dtypes
# Out:
# show_id               object
# type                  object
# title                 object
# director              object
# actors/actresses      object
# country               object
# Netflix_date_added    object
# release_year           int64
# rating                object
# duration              object
# categories            object
# description           object
# dtype: object

# %%
data['release_year'] = pd.to_datetime(data['release_year'].astype(str), format='%Y', errors='coerce').dt.year

# %%
data
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
data['Netflix_date_added'] = pd.to_datetime(data['Netflix_date_added'], errors='coerce')

# %%
str_cols = data.select_dtypes(include='object').columns
data[str_cols] = data[str_cols].apply(lambda x: x.str.strip())

# %%
data['duration'] = pd.to_numeric(data['duration'].astype(str).str.extract('(\d+)')[0], errors='coerce')

# %%
data.dtypes
# Out:
# show_id                       object
# type                          object
# title                         object
# director                      object
# actors/actresses              object
# country                       object
# Netflix_date_added    datetime64[ns]
# release_year                   int32
# rating                        object
# duration                     float64
# categories                    object
# description                   object
# dtype: object

# %%
data.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director              0
# actors/actresses      0
# country               0
# Netflix_date_added    5
# release_year          0
# rating                0
# duration              3
# categories            0
# description           0
# dtype: int64

# %%
data.fillna({'Netflix_date_added': data['Netflix_date_added'].mode()[0]}, inplace=True)

# %%
data.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director              0
# actors/actresses      0
# country               0
# Netflix_date_added    0
# release_year          0
# rating                0
# duration              3
# categories            0
# description           0
# dtype: int64

# %%
data['duration'] = pd.to_numeric(data['duration'].astype(str).str.extract('(\d+)')[0], errors='coerce')

# %%
data.dtypes
# Out:
# show_id                       object
# type                          object
# title                         object
# director                      object
# actors/actresses              object
# country                       object
# Netflix_date_added    datetime64[ns]
# release_year                   int32
# rating                        object
# duration                     float64
# categories                    object
# description                   object
# dtype: object

# %%
data['duration']=data['duration'].fillna('not available')

# %%
data.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director              0
# actors/actresses      0
# country               0
# Netflix_date_added    0
# release_year          0
# rating                0
# duration              0
# categories            0
# description           0
# dtype: int64

# %%
data
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
data['release_year'] = pd.to_datetime(data['release_year'], errors='coerce')
data['release_year'] = pd.to_datetime(data['release_year'].astype(str), format='%Y', errors='coerce').dt.year

# %%
data['duration'] = pd.to_numeric(data['duration'].astype(str).str.extract('(\d+)')[0], errors='coerce')

# %%
data.dtypes
# Out:
# show_id                       object
# type                          object
# title                         object
# director                      object
# actors/actresses              object
# country                       object
# Netflix_date_added    datetime64[ns]
# release_year                 float64
# rating                        object
# duration                     float64
# categories                    object
# description                   object
# dtype: object

# %%
data['duration']=data['duration'].fillna('not available')

# %%
data.isnull().sum()
# Out:
# show_id                  0
# type                     0
# title                    0
# director                 0
# actors/actresses         0
# country                  0
# Netflix_date_added       0
# release_year          6173
# rating                   0
# duration                 0
# categories               0
# description              0
# dtype: int64

# %%
data.dtypes
# Out:
# show_id                       object
# type                          object
# title                         object
# director                      object
# actors/actresses              object
# country                       object
# Netflix_date_added    datetime64[ns]
# release_year                 float64
# rating                        object
# duration                      object
# categories                    object
# description                   object
# dtype: object

# %%
data.to_csv("cleaned_data_analysis.csv", index=False)

# %%
data.to_csv("cleaned_data.csv", index=False)

# %%
import pandas as pd
! pip install pymysql sqlalchemy
from sqlalchemy import create_engine

# %%
data = pd.read_csv("cleaned_data.csv")
data
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 1         s3  TV Show                         Ganglands
# 2         s6  TV Show                     Midnight Mass
# 3         s7    Movie  My Little Pony: A New Generation
# 4         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 6168   s8802    Movie                           Zinzana
# 6169   s8803    Movie                            Zodiac
# 6170   s8805    Movie                        Zombieland
# 6171   s8806    Movie                              Zoom
# 6172   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 1                   Julien Leclercq
# 2                     Mike Flanagan
# 3     Robert Cullen, José Luis Ucha
# 4                      Haile Gerima
# ...                             ...
# ...

# %%
engine=create_engine("mysql+pymysql://root:8792@localhost:3307/project")

# %%
data.to_sql("netflix_data",con=engine,if_exists="replace",index=False)
# Out:
# 6173
